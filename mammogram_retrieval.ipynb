# %%
import numpy as np 
import pandas as pd 

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
from keras.models import Model
from pickle import dump

from keras.applications.vgg19 import preprocess_input
from keras.applications.vgg19 import decode_predictions
from keras.applications.vgg19 import VGG19

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

model = VGG16()
model = Model(inputs=model.inputs, outputs=model.layers[-2].output)

# %%
# %%time

from PIL import Image
from scipy.spatial import distance as ds
import operator
from operator import itemgetter


tab_euclidian={}
tab_euclidian1={}
euclidian={}
canberra={}
hamming={}
minkowski={}
chebyshev={}
dice={}
cosine={}
correlation={}

tab_canberra={}
tab_hamming={}
tab_chebyshev={}
tab_dice={}
tab_cosine={}
tab_correlation={}
tab_minkowski={}
for i in range(1,100):
    image='../input/traiiin/need+noNeed/Need biopsy/image_need_biopsy'+str(i)+'.jpg'
    image = load_img(image, target_size=(224, 224))
    # convert the image pixels to a numpy array
    image = img_to_array(image)
    # reshape data for the model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    # prepare the image for the VGG model
    image = preprocess_input(image)
    # get extracted features
    features = model.predict(image)
    
    
    ###
    tab_euclidian={}
    tab_euclidian1={}
    euclidian={}
    canberra={}
    hamming={}
    minkowski={}
    chebyshev={}
    dice={}
    cosine={}
    correlation={}

    tab_canberra={}
    tab_hamming={}
    tab_chebyshev={}
    tab_dice={}
    tab_cosine={}
    tab_correlation={}
    tab_minkowski={}
    ##



    for j in range(1,100):
     

        image1 = load_img('../input/traiiin/need+noNeed/Need biopsy/image_need_biopsy'+str(j)+'.jpg', target_size=(224, 224))
    # convert the image pixels to a numpy array
        image1 = img_to_array(image1)
    # reshape data for the model
        image1 = image1.reshape((1, image1.shape[0], image1.shape[1], image1.shape[2]))
    # prepare the image for the VGG model
        image1 = preprocess_input(image1)
        
    # get extracted features
        features1 = model.predict(image1)
    #print(features)
    
    ######
        euc_distance = np.linalg.norm(features - features1)
        canberra_distance= ds.canberra(features , features1)
        hamming_distance=ds.hamming(features,features1)
        minkowski_distance=ds.minkowski(features,features1)
        dice_distance=ds.dice(features,features1)
        chebyshev_distance=ds.chebyshev(features,features1)
        cosine_distance=ds.cosine(features,features1)
        correlation_distance=ds.correlation(features,features1)



        image_name='image_need_biopsy'+str(j)+'.jpg'

        tab_euclidian.update({image_name : euc_distance})
        tab_canberra.update({image_name : canberra_distance})
        tab_hamming.update({image_name : hamming_distance})
        tab_minkowski.update({image_name : minkowski_distance})  
        tab_dice.update({image_name : dice_distance})
        tab_chebyshev.update({image_name : chebyshev_distance})
        tab_cosine.update({image_name : cosine_distance})
        tab_correlation.update({image_name : correlation_distance})



##########
        
        
    ##

        image1 = load_img('../input/traiiin/need+noNeed/No need biopsy/image_no_need_biopsy'+str(j)+'.jpg', target_size=(224, 224))
    # convert the image pixels to a numpy array
        image1 = img_to_array(image1)
    # reshape data for the model
        image1 = image1.reshape((1, image1.shape[0], image1.shape[1], image1.shape[2]))
    # prepare the image for the VGG model
        image1 = preprocess_input(image1)
        
    # get extracted features
        features1 = model.predict(image1)
    #print(features)
    
    #####
        euc_distance = np.linalg.norm(features - features1)
        canberra_distance= ds.canberra(features , features1)
        hamming_distance=ds.hamming(features,features1)
        minkowski_distance=ds.minkowski(features,features1)
        dice_distance=ds.dice(features,features1)
        chebyshev_distance=ds.chebyshev(features,features1)
        cosine_distance=ds.cosine(features,features1)
        correlation_distance=ds.correlation(features,features1)

        image_name='image_no_need_biopsy'+str(j)+'.jpg'

        tab_euclidian.update({image_name : euc_distance})
        tab_canberra.update({image_name : canberra_distance})
        tab_hamming.update({image_name : hamming_distance})
        tab_minkowski.update({image_name : minkowski_distance})
        tab_dice.update({image_name : dice_distance})
        tab_chebyshev.update({image_name : chebyshev_distance})
        tab_cosine.update({image_name : cosine_distance})
        tab_correlation.update({image_name : correlation_distance})


#####
        image_name='image_need_biopsy'+str(i)+'.jpg'
        euclidian.update({image_name: tab_euclidian})
        canberra.update({image_name: tab_canberra})
        hamming.update({image_name: tab_hamming})
        minkowski.update({image_name: tab_minkowski})
        dice.update({image_name: tab_dice})
        chebyshev.update({image_name: tab_chebyshev})
        cosine.update({image_name: tab_cosine})
        correlation.update({image_name: tab_correlation})

#####
                ###euclidian
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    euclidian=euclidian['image_need_biopsy'+str(i)+'.jpg']
          
    sorted_dt = {key: value for key, value in sorted(euclidian.items(), key=lambda item: item[1])}
            
            
    for M in range(1,6):
        name=''
        for k in range(20):
            
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
            
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1
        

            
    result.append('image_need_biopsy'+str(i)+'.jpg : euclidian distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')

###
    ### canberra


#####
                ###canberra
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    canberra=canberra['image_need_biopsy'+str(i)+'.jpg']
    sorted_dt = {key: value for key, value in sorted(canberra.items(), key=lambda item: item[1])}
            
            
    for M in range(1,6):
        name=''
        for k in range(20):
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1

            
    result.append('image_need_biopsy'+str(i)+'.jpg : canberra distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')

###

    
    
#####
                ###hamming
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    hamming=hamming['image_need_biopsy'+str(i)+'.jpg']
    
    sorted_dt = {key: value for key, value in sorted(hamming.items(), key=lambda item: item[1])}
            
    
                
            
    for M in range(1,6):
        name=''
        for k in range(20):
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1

            
    result.append('image_need_biopsy'+str(i)+'.jpg : hamming distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')

        
    
#####
                ###minkowski
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    minkowski=minkowski['image_need_biopsy'+str(i)+'.jpg']
    
           
    sorted_dt = {key: value for key, value in sorted(minkowski.items(), key=lambda item: item[1])}

    
             
    for M in range(1,6):
        name=''
        for k in range(20):
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1
        

            
    result.append('image_need_biopsy'+str(i)+'.jpg : minkowski distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')


    #####
                ###dice
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    dice=dice['image_need_biopsy'+str(i)+'.jpg']
    
    sorted_dt = {key: value for key, value in sorted(dice.items(), key=lambda item: item[1])}
          

    for M in range(1,6):
        name=''
        for k in range(20):
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1

            
    result.append('image_need_biopsy'+str(i)+'.jpg : dice distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')


    #####
                ###chebyshev
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    chebyshev=chebyshev['image_need_biopsy'+str(i)+'.jpg']
    
    sorted_dt = {key: value for key, value in sorted(chebyshev.items(), key=lambda item: item[1])}
           
    for M in range(1,6):
        name=''
        for k in range(20):
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1

            
    result.append('image_need_biopsy'+str(i)+'.jpg : chebyshev distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')

        #####
                ###cosine
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    cosine=cosine['image_need_biopsy'+str(i)+'.jpg']
    
    sorted_dt = {key: value for key, value in sorted(cosine.items(), key=lambda item: item[1])}
     
            
    for M in range(1,6):
        name=''
        for k in range(20):
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1

            
    result.append('image_need_biopsy'+str(i)+'.jpg : cosine distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')

            #####
                ###correlation
    nb_need_biopsy=0
    nb_no_need_biopsy=0
    result=[]
    correlation=correlation['image_need_biopsy'+str(i)+'.jpg']
    
    sorted_dt = {key: value for key, value in sorted(correlation.items(), key=lambda item: item[1])}
       
            
    for M in range(1,6):
        name=''
        for k in range(20):
            name=name+list(sorted_dt.keys())[M][k]
        print(list(sorted_dt.keys())[M])
        if('image_no_need_biopsy'== name):
            nb_no_need_biopsy=nb_no_need_biopsy+1
        else:
            nb_need_biopsy=nb_need_biopsy+1

            
    result.append('image_need_biopsy'+str(i)+'.jpg : correlation distance '+': '+str(nb_need_biopsy)+' need biopsy, '+str(nb_no_need_biopsy)+' no need biopsy')
    print(result)
    print('\n')

print("done")
